# %%
import numpy as np
import pandas as pd

# %%
np.set_printoptions(precision=2)

# %% [markdown]
# **Считываем данные из файла**

# %%
data = pd.read_csv("../data/spotify-2023.csv", encoding='ISO-8859-1')

# %%
df = data #заренеймим

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Смотрим на первые 5 строк**

# %%
data.head(5)
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
data.tail(7).T
# Out:
#                                    946            947           948  \
# track_name                  Broke Boys  The Great War  My Mind & Me
# artist(s)_name        Drake, 21 Savage   Taylor Swift  Selena Gomez
# artist_count                         2              1             1
# released_year                     2022           2022          2022
# released_month                      11             10            11
# released_day                         4             21             3
# in_spotify_playlists              1060           1274           953
# in_spotify_charts                    0              0             0
# streams                      106249219      181382590      91473363
# in_apple_playlists                   3              1            61
# in_apple_charts                      8              6            13
# in_deezer_playlists                  5             11            37
# in_deezer_charts                     0              0             1
# ...

# %%
data.shape
# Out:
# (953, 24)

# %% [markdown]
# **Краткая статистика – info и describe**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
data.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %% [markdown]
# **Индексация**

# %%
df.loc[:5, ["track_name", "in_spotify_playlists"]]
# Out:
#                             track_name  in_spotify_playlists
# 0  Seven (feat. Latto) (Explicit Ver.)                   553
# 1                                 LALA                  1474
# 2                              vampire                  1397
# 3                         Cruel Summer                  7858
# 4                       WHERE SHE GOES                  3133
# 5                             Sprinter                  2186

# %% [markdown]
# **loc и iloc**

# %%
df.iloc[:7, 0:5]
# Out:
#                             track_name              artist(s)_name  \
# 0  Seven (feat. Latto) (Explicit Ver.)            Latto, Jung Kook
# 1                                 LALA                 Myke Towers
# 2                              vampire              Olivia Rodrigo
# 3                         Cruel Summer                Taylor Swift
# 4                       WHERE SHE GOES                   Bad Bunny
# 5                             Sprinter           Dave, Central Cee
# 6                      Ella Baila Sola  Eslabon Armado, Peso Pluma
#
#    artist_count  released_year  released_month
# 0             2           2023               7
# 1             1           2023               3
# 2             1           2023               6
# 3             1           2019               8
# 4             1           2023               5
# 5             2           2023               6
# 6             2           2023               3

# %%
 df.iloc[:7, 0:5], df.iloc[:7, 10:12]
# Out:
# (                            track_name              artist(s)_name  \
#  0  Seven (feat. Latto) (Explicit Ver.)            Latto, Jung Kook
#  1                                 LALA                 Myke Towers
#  2                              vampire              Olivia Rodrigo
#  3                         Cruel Summer                Taylor Swift
#  4                       WHERE SHE GOES                   Bad Bunny
#  5                             Sprinter           Dave, Central Cee
#  6                      Ella Baila Sola  Eslabon Armado, Peso Pluma
#
#     artist_count  released_year  released_month
#  0             2           2023               7
#  1             1           2023               3
#  2             1           2023               6
#  3             1           2019               8
#  4             1           2023               5
#  5             2           2023               6
#  6             2           2023               3  ,
# ...

# %%
type(df.iloc[:7, 0:5])
# Out:
# pandas.core.frame.DataFrame

# %%
data.loc[0:5, ["track_name", "released_year"]]
# Out:
#                             track_name  released_year
# 0  Seven (feat. Latto) (Explicit Ver.)           2023
# 1                                 LALA           2023
# 2                              vampire           2023
# 3                         Cruel Summer           2019
# 4                       WHERE SHE GOES           2023
# 5                             Sprinter           2023

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
df[df['released_month'] == 7]['in_apple_playlists'].mean(numeric_only=True)
# Out:
# 66.61290322580645

# %%
data.iloc[:, 2:4].head()
# Out:
#    artist_count  released_year
# 0             2           2023
# 1             1           2023
# 2             1           2023
# 3             1           2019
# 4             1           2023

# %% [markdown]
# **Логическая индексация**

# %%
df[(df["released_month"] == 7) & (df["in_spotify_charts"] <100)]['track_name']
# Out:
# 7                                               Columbia
# 11                                             Super Shy
# 21     I Can See You (Taylorï¿½ï¿½ï¿½s Version) (From...
# 30                                                  Rush
# 43                                         See You Again
# 58                                                   S91
# 59                                              cardigan
# 68                                             Overdrive
# 69                          Enchanted (Taylor's Version)
# 72                                           golden hour
# 74                 Quevedo: Bzrp Music Sessions, Vol. 52
# 76                                          Here With Me
# 83                   Back To December (Taylor's Version)
# 84                             STAY (with Justin Bieber)
# 104                                            New Jeans
# 113                              Mine (Taylor's Version)
# ...

# %%
df[(df["released_month"] == 7) & (df["in_spotify_charts"] <100)]['in_spotify_playlists'].mean()
# Out:
# 3868.7166666666667

# %%
df[(df["released_month"] == 7) & (df["in_spotify_charts"] <100)]['in_spotify_playlists'].median()
# Out:
# 2333.5

# %%
abs(df[(df["released_month"] == 7) & (df["in_spotify_charts"] <100)]['in_spotify_playlists'].median() - df[(df["released_month"] == 7) & (df["in_spotify_charts"] <100)]['in_spotify_playlists'].mean())
# Out:
# 1535.2166666666667

# %% [markdown]
# **Groupby**

# %%
type(df.groupby('released_month'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
for  month in df.groupby('released_month'):
    print(type(month))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>

# %%
for  var, month in df.groupby('released_month'):
    print( month['in_spotify_playlists'].mean() )
# Out:
# 10685.492537313432
# 3419.72131147541
# 4057.953488372093
# 3258.030303030303
# 3392.1875
# 3538.5232558139537
# 3766.9193548387098
# 5772.347826086957
# 7731.089285714285
# 5772.671232876713
# 5532.225
# 2889.76

# %%
df.loc[0:5,[ "track_name", "released_year", "in_spotify_charts", "in_spotify_playlists"]]
# Out:
#                             track_name  released_year  in_spotify_charts  \
# 0  Seven (feat. Latto) (Explicit Ver.)           2023                147
# 1                                 LALA           2023                 48
# 2                              vampire           2023                113
# 3                         Cruel Summer           2019                100
# 4                       WHERE SHE GOES           2023                 50
# 5                             Sprinter           2023                 91
#
#    in_spotify_playlists
# 0                   553
# 1                  1474
# 2                  1397
# 3                  7858
# 4                  3133
# 5                  2186

# %%
df.groupby('released_month')

# %%
df.groupby('released_month')[ ['in_spotify_charts', 'in_spotify_playlists'] ].agg(np.mean)
# Out:
# C:\Users\User1\AppData\Local\Temp\ipykernel_672\1971928967.py:1: FutureWarning: The provided callable <function mean at 0x0000013151F2C4A0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby('released_month')[ ['in_spotify_charts', 'in_spotify_playlists'] ].agg(np.mean)
#                 in_spotify_charts  in_spotify_playlists
# released_month
# 1                       11.455224          10685.492537
# 2                       13.868852           3419.721311
# 3                       13.244186           4057.953488
# 4                       11.454545           3258.030303
# 5                       10.164062           3392.187500
# 6                       16.790698           3538.523256
# 7                       21.500000           3766.919355
# 8                       11.913043           5772.347826
# ...

# %%
data2 = df.groupby('released_month')[ ['in_spotify_charts', 'in_spotify_playlists'] ].agg(np.std)
# Out:
# C:\Users\User1\AppData\Local\Temp\ipykernel_672\3808899873.py:1: FutureWarning: The provided callable <function std at 0x0000013151F2C5E0> is currently using DataFrameGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   data2 = df.groupby('released_month')[ ['in_spotify_charts', 'in_spotify_playlists'] ].agg(np.std)

# %%
data2.sort_values(by=['in_spotify_charts'])
# Out:
#                 in_spotify_charts  in_spotify_playlists
# released_month
# 9                       13.490726          11255.806216
# 11                      15.151367           7523.368420
# 10                      15.907995           8663.337074
# 4                       17.194974           5848.236281
# 2                       17.320966           6359.237740
# 12                      18.117067           3984.970226
# 5                       18.175339           4858.566093
# 1                       19.940745          12031.401274
# 8                       20.670780           6970.010025
# 3                       21.724985           5700.647732
# 6                       23.489230           5059.662636
# 7                       26.967345           4358.993331

# %% [markdown]
# **Сводная таблица**

# %%
pd.crosstab( df['released_month'], df['artist_count'])
# Out:
# artist_count     1   2   3  4  5  6  7  8
# released_month
# 1               98  22  11  2  0  0  1  0
# 2               32  25   3  0  0  1  0  0
# 3               48  29   8  1  0  0  0  0
# 4               39  23   4  0  0  0  0  0
# 5               81  34   9  2  2  0  0  0
# 6               41  27  11  4  2  0  0  1
# 7               42  10   9  1  0  0  0  0
# 8               29  10   4  2  0  0  0  1
# 9               33  14   7  2  0  0  0  0
# 10              56  13   4  0  0  0  0  0
# 11              43  28   8  0  0  0  1  0
# 12              45  19   7  1  1  2  0  0

# %%
df['artist_count'].describe()
# Out:
# count    953.000000
# mean       1.556139
# std        0.893044
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        8.000000
# Name: artist_count, dtype: float64

# %%
df.artist_count.describe()
# Out:
# count    953.000000
# mean       1.556139
# std        0.893044
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        8.000000
# Name: artist_count, dtype: float64

# %%
df['track_name'] = df['artist_count'] > df['artist_count'].quantile(.75)

# %%
df['artist_count'] > df['artist_count'].quantile(.75)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 948    False
# 949    False
# 950    False
# 951     True
# 952    False
# Name: artist_count, Length: 953, dtype: bool

# %%
df['artist_count'].quantile(.75)
# Out:
# 2.0

# %%
(df['artist_count'] > df['artist_count'].quantile(.5)).astype('int64')
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 948    0
# 949    0
# 950    1
# 951    1
# 952    0
# Name: artist_count, Length: 953, dtype: int64

# %%
pd.crosstab(data["female"], data["looks"])

# %% [markdown]
# **Добавление столбцов (построение признаков)**

# %%
df['new_feat'] = (df['artist_count'] > df['artist_count'].quantile(.5)).astype('int64')

# %%
df.head()
# Out:
#    track_name    artist(s)_name  artist_count  released_year  released_month  \
# 0       False  Latto, Jung Kook             2           2023               7
# 1       False       Myke Towers             1           2023               3
# 2       False    Olivia Rodrigo             1           2023               6
# 3       False      Taylor Swift             1           2019               8
# 4       False         Bad Bunny             1           2023               5
#
#    released_day  in_spotify_playlists  in_spotify_charts    streams  \
# 0            14                   553                147  141381703
# 1            23                  1474                 48  133716286
# 2            30                  1397                113  140003974
# 3            23                  7858                100  800840817
# 4            18                  3133                 50  303236322
#
#    in_apple_playlists  ...  key   mode  danceability_% valence_%  energy_%  \
# ...

# %%
df['new_feat_2'] = .56*df['released_year'] + .32*df['in_spotify_playlists']

# %% [markdown]
# **map и apply**

# %%
def func1(released_month):
    return ('happy_bd' if released_month ==7  else 'no :)')

# %%
func1(7), func1(8)
# Out:
# ('happy_bd', 'no :)')

# %%
df["released_month"].apply(func1)
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 953 entries, 0 to 952
# Series name: released_month
# Non-Null Count  Dtype
# --------------  -----
# 953 non-null    object
# dtypes: object(1)
# memory usage: 7.6+ KB

# %%
df[df["released_month"].apply(func1) =='happy_bd']
# Out:
#      track_name                      artist(s)_name  artist_count  \
# 0         False                    Latto, Jung Kook             2
# 7         False                             Quevedo             1
# 11        False                            NewJeans             1
# 17        False                       Billie Eilish             1
# 21        False                        Taylor Swift             1
# ..          ...                                 ...           ...
# 909       False                          Steve Lacy             1
# 911       False                            Coldplay             1
# 915       False           Ovy On The Drums, Quevedo             2
# 924       False                               Lizzo             1
# 930        True  MC Ryan SP, Love Funk, Mc Paiva ZS             3
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 0             2023               7            14                   553
# ...

# %%
df["released_month"].apply(lambda released_month:'happy_bd' if released_month ==7  else 'no :)' )
# Out:
# 0      happy_bd
# 1         no :)
# 2         no :)
# 3         no :)
# 4         no :)
#          ...
# 948       no :)
# 949       no :)
# 950       no :)
# 951       no :)
# 952       no :)
# Name: released_month, Length: 953, dtype: object

# %%
d = {'happy_bd': 1, 'no :)': 0}

# %%
df["released_month"].apply(lambda released_month:'happy_bd' if released_month ==7  else 'no :)' ).map(d).head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    0
# Name: released_month, dtype: int64
